# %% [markdown]
# 기능별 collection 생성

# %%
import os
import json
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.documents import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate
import chromadb
from glob import glob

#API Key 설정 
os.environ["OPENAI_API_KEY"] = ""

#임베딩 모델 초기화 
embeddings_model = OpenAIEmbeddings(model = 'text-embedding-3-small')

#json-> text 파일을 청크로 분할
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

# Chroma 클라이언트
client = chromadb.PersistentClient(path="./chroma_db")

#json -> documents 파일 변환

def load_json_documents(json_files):
    docs = []
    for file in json_files:
        with open(file, "r", encoding="utf-8") as f:
            data = json.load(f)

        #시나리오
        for item in data:
            if "Text" in item and "Completion" in item:
                docs.append(Document(
                    page_content=f"질문: {item['Text']}\n답변: {item['Completion']}",
                    metadata={
                        "카테고리": item.get("카테고리", "")
                    }
                ))

            # 수강이력
            if "lecture_name" in item and "student_id" in item:
                content = (
                    f"학번: {item['student_id']}\n"
                    f"강의명: {item['lecture_name']}\n"
                    f"학정번호: {item['lecture_id']}\n"
                    f"개설 학과: {item['department_offered']}\n"
                    f"이수 구분: {item['lecture_course_type']}\n"
                    f"학점: {item['lecture_credit']}학점\n"
                    f"성적: {item['lecutre_grade']}"
                )
                if "retake_or_delete_status" in item:
                    content += f"\n재수강/삭제 여부: {item['retake_or_delete_status']}"
                if "retake_status" in item:
                    content += f"\n재수강 여부: {item['retake_status']}"

                docs.append(Document(
                    page_content=content,
                    metadata={
                        "lecture_name": item["lecture_name"],
                        "course_type": item["lecture_course_type"]
                    }
                ))

            # 강의 탐색
            if "lecture_id" in item and "lecture_name" in item and "student_id" not in item:
                content = (
                    f"학정번호: {item.get('lecture_id', '')}\n"
                    f"강의명: {item.get('lecture_name', '')}\n"
                    f"강의평점: {item.get('lecture_ratings', '')}\n"
                    f"과제: {item.get('lecture_homework', '')}\n"
                    f"팀플: {item.get('lecture_team', '')}\n"
                    f"성적평가정도: {item.get('lecutre_grade', '')}\n"
                    f"출결 방식: {item.get('lecutre_attendance', '')}\n"
                    f"시험 횟수: {item.get('lecutre_test', '')}\n"
                    f"시험 방식: {item.get('lecture_testinform', '')}\n"
                    f"전공 학점: {item.get('credits_major', '없음')}\n"
                    f"교양 학점: {item.get('credits_general', '없음')}\n"
                    f"총 학점: {item.get('credits_total', '없음')}\n"
                    f"교수명: {item.get('lecture_professorname', '')}\n"
                    f"수업 시간: {item.get('lecture_time', '')}\n"
                    f"강의 유형: {item.get('lecture_course_type', '')}\n"
                    f"학점: {item.get('lecture_hours', '')}시간\n"
                    f"학기: {item.get('lecture_semester', '')}학기\n"
                    f"강의 설명: {item.get('lecture_inform', '')}"
                )
                docs.append(Document(
                    page_content=content,
                    metadata={
                        "lecture_id": item.get("lecture_id", ""),
                        "lecture_name": item.get("lecture_name", ""),
                        "lecture_ratings": item.get("lecture_ratings", ""),
                        "lecture_team": item.get("lecture_team", ""),
                        "lecutre_grade": item.get("lecutre_grade", ""),
                        "professor": item.get("lecture_professorname", "")
                    }
                ))
    return docs


base_path = r"C:\Users\82103\OneDrive\바탕 화면\data"

user_datasets = {
    "kim": glob(os.path.join(base_path, "academic_status", "kim", "*.json")),
    "hong": glob(os.path.join(base_path, "academic_status", "hong", "*.json"))
}


task_datasets = {
    task: glob(os.path.join(base_path, task, "*.json"))
    for task in ["lecture_search", "career_counsel", "academic_status"]
}

# 각 기능별 컬렉션 생성 및 임베딩 처리
for task, files in task_datasets.items():
    # JSON → Documents
    docs = load_json_documents(files)

    #청크 분할
    split_docs = text_splitter.split_documents(docs)

    # 청크 텍스트
    texts = [doc.page_content for doc in split_docs]

    # 임베딩
    embeddings = embeddings_model.embed_documents(texts)

    # 저장
    collection = client.get_or_create_collection(name=task)
    collection.add(
        documents=texts,
        embeddings=embeddings,
        ids=[f"{task}_{i}" for i in range(len(texts))]
    )
    
    print("임베딩 개수:", len(embeddings))
    print("벡터 차원:", len(embeddings[0]))
# Out:
# Insert of existing embedding ID: lecture_search_0
# Insert of existing embedding ID: lecture_search_1
# Insert of existing embedding ID: lecture_search_2
# Insert of existing embedding ID: lecture_search_3
# Insert of existing embedding ID: lecture_search_4
# Insert of existing embedding ID: lecture_search_5
# Insert of existing embedding ID: lecture_search_6
# Insert of existing embedding ID: lecture_search_7
# Insert of existing embedding ID: lecture_search_8
# Insert of existing embedding ID: lecture_search_9
# Insert of existing embedding ID: lecture_search_10
# Insert of existing embedding ID: lecture_search_11
# Insert of existing embedding ID: lecture_search_12
# Insert of existing embedding ID: lecture_search_13
# Insert of existing embedding ID: lecture_search_14
# Insert of existing embedding ID: lecture_search_15
# Insert of existing embedding ID: lecture_search_16
# Insert of existing embedding ID: lecture_search_17
# Insert of existing embedding ID: lecture_search_18
# Insert of existing embedding ID: lecture_search_19
# Insert of existing embedding ID: lecture_search_20
# Insert of existing embedding ID: lecture_search_21
# Insert of existing embedding ID: lecture_search_22
# Insert of existing embedding ID: lecture_search_23
# Insert of existing embedding ID: lecture_search_24
# Insert of existing embedding ID: lecture_search_25
# Insert of existing embedding ID: lecture_search_26
# Insert of existing embedding ID: lecture_search_27
# Insert of existing embedding ID: lecture_search_28
# Insert of existing embedding ID: lecture_search_29
# Insert of existing embedding ID: lecture_search_30
# Insert of existing embedding ID: lecture_search_31
# Insert of existing embedding ID: lecture_search_32
# Insert of existing embedding ID: lecture_search_33
# Insert of existing embedding ID: lecture_search_34
# Insert of existing embedding ID: lecture_search_35
# Insert of existing embedding ID: lecture_search_36
# Insert of existing embedding ID: lecture_search_37
# Insert of existing embedding ID: lecture_search_38
# Insert of existing embedding ID: lecture_search_39
# Insert of existing embedding ID: lecture_search_40
# Insert of existing embedding ID: lecture_search_41
# Insert of existing embedding ID: lecture_search_42
# Insert of existing embedding ID: lecture_search_43
# Insert of existing embedding ID: lecture_search_44
# Insert of existing embedding ID: lecture_search_45
# Insert of existing embedding ID: lecture_search_46
# Insert of existing embedding ID: lecture_search_47
# Insert of existing embedding ID: lecture_search_48
# Insert of existing embedding ID: lecture_search_49
# Insert of existing embedding ID: lecture_search_50
# Insert of existing embedding ID: lecture_search_51
# Insert of existing embedding ID: lecture_search_52
# Insert of existing embedding ID: lecture_search_53
# Insert of existing embedding ID: lecture_search_54
# Insert of existing embedding ID: lecture_search_55
# Insert of existing embedding ID: lecture_search_574
# Insert of existing embedding ID: lecture_search_575
# Insert of existing embedding ID: lecture_search_576
# Insert of existing embedding ID: lecture_search_577
# Insert of existing embedding ID: lecture_search_578
# Insert of existing embedding ID: lecture_search_579
# Insert of existing embedding ID: lecture_search_580
# Insert of existing embedding ID: lecture_search_581
# Insert of existing embedding ID: lecture_search_582
# Insert of existing embedding ID: lecture_search_583
# Insert of existing embedding ID: lecture_search_584
# Insert of existing embedding ID: lecture_search_585
# Insert of existing embedding ID: lecture_search_586
# Insert of existing embedding ID: lecture_search_587
# Insert of existing embedding ID: lecture_search_588
# Insert of existing embedding ID: lecture_search_589
# Insert of existing embedding ID: lecture_search_590
# Insert of existing embedding ID: lecture_search_591
# Insert of existing embedding ID: lecture_search_592
# Insert of existing embedding ID: lecture_search_593
# Insert of existing embedding ID: lecture_search_594
# Insert of existing embedding ID: lecture_search_595
# Insert of existing embedding ID: lecture_search_596
# Insert of existing embedding ID: lecture_search_597
# Insert of existing embedding ID: lecture_search_598
# Insert of existing embedding ID: lecture_search_599
# Insert of existing embedding ID: lecture_search_600
# Insert of existing embedding ID: lecture_search_601
# Insert of existing embedding ID: lecture_search_602
# Insert of existing embedding ID: lecture_search_603
# Insert of existing embedding ID: lecture_search_604
# Insert of existing embedding ID: lecture_search_605
# Insert of existing embedding ID: lecture_search_606
# Insert of existing embedding ID: lecture_search_607
# Insert of existing embedding ID: lecture_search_608
# Add of existing embedding ID: lecture_search_0
# Add of existing embedding ID: lecture_search_1
# Add of existing embedding ID: lecture_search_2
# Add of existing embedding ID: lecture_search_3
# Add of existing embedding ID: lecture_search_4
# Add of existing embedding ID: lecture_search_5
# Add of existing embedding ID: lecture_search_6
# Add of existing embedding ID: lecture_search_7
# Add of existing embedding ID: lecture_search_8
# Add of existing embedding ID: lecture_search_9
# Add of existing embedding ID: lecture_search_10
# Add of existing embedding ID: lecture_search_11
# Add of existing embedding ID: lecture_search_12
# Add of existing embedding ID: lecture_search_13
# Add of existing embedding ID: lecture_search_14
# Add of existing embedding ID: lecture_search_15
# Add of existing embedding ID: lecture_search_16
# Add of existing embedding ID: lecture_search_17
# Add of existing embedding ID: lecture_search_18
# Add of existing embedding ID: lecture_search_19
# Add of existing embedding ID: lecture_search_20
# Add of existing embedding ID: lecture_search_21
# Add of existing embedding ID: lecture_search_22
# Add of existing embedding ID: lecture_search_23
# Add of existing embedding ID: lecture_search_24
# Add of existing embedding ID: lecture_search_25
# Add of existing embedding ID: lecture_search_26
# Add of existing embedding ID: lecture_search_27
# Add of existing embedding ID: lecture_search_28
# Add of existing embedding ID: lecture_search_29
# Add of existing embedding ID: lecture_search_30
# Add of existing embedding ID: lecture_search_31
# Add of existing embedding ID: lecture_search_32
# Add of existing embedding ID: lecture_search_33
# Add of existing embedding ID: lecture_search_34
# Add of existing embedding ID: lecture_search_35
# Add of existing embedding ID: lecture_search_36
# Add of existing embedding ID: lecture_search_37
# Add of existing embedding ID: lecture_search_38
# Add of existing embedding ID: lecture_search_39
# Add of existing embedding ID: lecture_search_40
# Add of existing embedding ID: lecture_search_41
# Add of existing embedding ID: lecture_search_42
# Add of existing embedding ID: lecture_search_43
# Add of existing embedding ID: lecture_search_44
# Add of existing embedding ID: lecture_search_45
# Add of existing embedding ID: lecture_search_46
# Add of existing embedding ID: lecture_search_47
# Add of existing embedding ID: lecture_search_48
# Add of existing embedding ID: lecture_search_49
# Add of existing embedding ID: lecture_search_50
# Add of existing embedding ID: lecture_search_51
# Add of existing embedding ID: lecture_search_52
# Add of existing embedding ID: lecture_search_53
# Add of existing embedding ID: lecture_search_54
# Add of existing embedding ID: lecture_search_55
# Add of existing embedding ID: lecture_search_56
# Add of existing embedding ID: lecture_search_57
# Add of existing embedding ID: lecture_search_58
# Add of existing embedding ID: lecture_search_59
# Add of existing embedding ID: lecture_search_60
# Add of existing embedding ID: lecture_search_61
# Add of existing embedding ID: lecture_search_62
# Add of existing embedding ID: lecture_search_63
# Add of existing embedding ID: lecture_search_64
# Add of existing embedding ID: lecture_search_65
# Add of existing embedding ID: lecture_search_66
# Add of existing embedding ID: lecture_search_67
# Add of existing embedding ID: lecture_search_68
# Add of existing embedding ID: lecture_search_69
# Add of existing embedding ID: lecture_search_70
# Add of existing embedding ID: lecture_search_71
# Add of existing embedding ID: lecture_search_72
# Add of existing embedding ID: lecture_search_73
# Add of existing embedding ID: lecture_search_74
# Add of existing embedding ID: lecture_search_75
# Add of existing embedding ID: lecture_search_76
# Add of existing embedding ID: lecture_search_77
# Add of existing embedding ID: lecture_search_78
# Add of existing embedding ID: lecture_search_79
# Add of existing embedding ID: lecture_search_80
# Add of existing embedding ID: lecture_search_81
# Add of existing embedding ID: lecture_search_82
# Add of existing embedding ID: lecture_search_83
# Add of existing embedding ID: lecture_search_84
# Add of existing embedding ID: lecture_search_85
# Add of existing embedding ID: lecture_search_86
# Add of existing embedding ID: lecture_search_87
# Add of existing embedding ID: lecture_search_88
# Add of existing embedding ID: lecture_search_89
# Add of existing embedding ID: lecture_search_90
# Add of existing embedding ID: lecture_search_91
# Add of existing embedding ID: lecture_search_92
# Add of existing embedding ID: lecture_search_93
# Add of existing embedding ID: lecture_search_94
# Add of existing embedding ID: lecture_search_95
# Add of existing embedding ID: lecture_search_96
# Add of existing embedding ID: lecture_search_97
# Add of existing embedding ID: lecture_search_98
# Add of existing embedding ID: lecture_search_99
# Add of existing embedding ID: lecture_search_100
# Add of existing embedding ID: lecture_search_101
# Add of existing embedding ID: lecture_search_102
# Add of existing embedding ID: lecture_search_103
# Add of existing embedding ID: lecture_search_104
# Add of existing embedding ID: lecture_search_105
# Add of existing embedding ID: lecture_search_106
# Add of existing embedding ID: lecture_search_107
# Add of existing embedding ID: lecture_search_108
# Add of existing embedding ID: lecture_search_109
# Add of existing embedding ID: lecture_search_110
# Add of existing embedding ID: lecture_search_111
# Add of existing embedding ID: lecture_search_112
# Add of existing embedding ID: lecture_search_113
# Add of existing embedding ID: lecture_search_114
# Add of existing embedding ID: lecture_search_115
# Add of existing embedding ID: lecture_search_116
# Add of existing embedding ID: lecture_search_117
# Add of existing embedding ID: lecture_search_118
# Add of existing embedding ID: lecture_search_119
# Add of existing embedding ID: lecture_search_120
# Add of existing embedding ID: lecture_search_121
# Add of existing embedding ID: lecture_search_122
# Add of existing embedding ID: lecture_search_123
# Add of existing embedding ID: lecture_search_124
# Add of existing embedding ID: lecture_search_125
# Add of existing embedding ID: lecture_search_126
# Add of existing embedding ID: lecture_search_127
# Add of existing embedding ID: lecture_search_128
# Add of existing embedding ID: lecture_search_129
# Add of existing embedding ID: lecture_search_130
# Add of existing embedding ID: lecture_search_131
# Add of existing embedding ID: lecture_search_132
# Add of existing embedding ID: lecture_search_133
# Add of existing embedding ID: lecture_search_134
# Add of existing embedding ID: lecture_search_135
# Add of existing embedding ID: lecture_search_136
# Add of existing embedding ID: lecture_search_137
# Add of existing embedding ID: lecture_search_138
# Add of existing embedding ID: lecture_search_139
# Add of existing embedding ID: lecture_search_140
# Add of existing embedding ID: lecture_search_141
# Add of existing embedding ID: lecture_search_142
# Add of existing embedding ID: lecture_search_143
# Add of existing embedding ID: lecture_search_144
# Add of existing embedding ID: lecture_search_145
# Add of existing embedding ID: lecture_search_146
# Add of existing embedding ID: lecture_search_147
# Add of existing embedding ID: lecture_search_148
# Add of existing embedding ID: lecture_search_149
# Add of existing embedding ID: lecture_search_150
# Add of existing embedding ID: lecture_search_151
# Add of existing embedding ID: lecture_search_152
# Add of existing embedding ID: lecture_search_153
# Add of existing embedding ID: lecture_search_154
# Add of existing embedding ID: lecture_search_155
# Add of existing embedding ID: lecture_search_156
# Add of existing embedding ID: lecture_search_157
# Add of existing embedding ID: lecture_search_158
# Add of existing embedding ID: lecture_search_159
# Add of existing embedding ID: lecture_search_160
# Add of existing embedding ID: lecture_search_161
# Add of existing embedding ID: lecture_search_162
# Add of existing embedding ID: lecture_search_163
# Add of existing embedding ID: lecture_search_164
# Add of existing embedding ID: lecture_search_165
# Add of existing embedding ID: lecture_search_166
# Add of existing embedding ID: lecture_search_167
# Add of existing embedding ID: lecture_search_168
# Add of existing embedding ID: lecture_search_169
# Add of existing embedding ID: lecture_search_170
# Add of existing embedding ID: lecture_search_171
# Add of existing embedding ID: lecture_search_172
# Add of existing embedding ID: lecture_search_173
# Add of existing embedding ID: lecture_search_174
# Add of existing embedding ID: lecture_search_175
# Add of existing embedding ID: lecture_search_176
# Add of existing embedding ID: lecture_search_177
# Add of existing embedding ID: lecture_search_178
# Add of existing embedding ID: lecture_search_179
# Add of existing embedding ID: lecture_search_180
# Add of existing embedding ID: lecture_search_181
# Add of existing embedding ID: lecture_search_182
# Add of existing embedding ID: lecture_search_183
# Add of existing embedding ID: lecture_search_184
# Add of existing embedding ID: lecture_search_185
# Add of existing embedding ID: lecture_search_186
# Add of existing embedding ID: lecture_search_187
# Add of existing embedding ID: lecture_search_188
# Add of existing embedding ID: lecture_search_189
# Add of existing embedding ID: lecture_search_190
# Add of existing embedding ID: lecture_search_191
# Add of existing embedding ID: lecture_search_192
# Add of existing embedding ID: lecture_search_193
# Add of existing embedding ID: lecture_search_194
# Add of existing embedding ID: lecture_search_195
# Add of existing embedding ID: lecture_search_196
# Add of existing embedding ID: lecture_search_197
# Add of existing embedding ID: lecture_search_198
# Add of existing embedding ID: lecture_search_199
# Add of existing embedding ID: lecture_search_200
# Add of existing embedding ID: lecture_search_201
# Add of existing embedding ID: lecture_search_202
# Add of existing embedding ID: lecture_search_203
# Add of existing embedding ID: lecture_search_204
# Add of existing embedding ID: lecture_search_205
# Add of existing embedding ID: lecture_search_206
# Add of existing embedding ID: lecture_search_207
# Add of existing embedding ID: lecture_search_208
# Add of existing embedding ID: lecture_search_209
# Add of existing embedding ID: lecture_search_210
# Add of existing embedding ID: lecture_search_211
# Add of existing embedding ID: lecture_search_212
# Add of existing embedding ID: lecture_search_213
# Add of existing embedding ID: lecture_search_214
# Add of existing embedding ID: lecture_search_215
# Add of existing embedding ID: lecture_search_216
# Add of existing embedding ID: lecture_search_217
# Add of existing embedding ID: lecture_search_218
# Add of existing embedding ID: lecture_search_219
# Add of existing embedding ID: lecture_search_220
# Add of existing embedding ID: lecture_search_221
# Add of existing embedding ID: lecture_search_222
# Add of existing embedding ID: lecture_search_223
# Add of existing embedding ID: lecture_search_224
# Add of existing embedding ID: lecture_search_225
# Add of existing embedding ID: lecture_search_226
# Add of existing embedding ID: lecture_search_227
# Add of existing embedding ID: lecture_search_228
# Add of existing embedding ID: lecture_search_229
# Add of existing embedding ID: lecture_search_230
# Add of existing embedding ID: lecture_search_231
# Add of existing embedding ID: lecture_search_232
# Add of existing embedding ID: lecture_search_233
# Add of existing embedding ID: lecture_search_234
# Add of existing embedding ID: lecture_search_235
# Add of existing embedding ID: lecture_search_236
# Add of existing embedding ID: lecture_search_237
# Add of existing embedding ID: lecture_search_238
# Add of existing embedding ID: lecture_search_239
# Add of existing embedding ID: lecture_search_240
# Add of existing embedding ID: lecture_search_241
# Add of existing embedding ID: lecture_search_242
# Add of existing embedding ID: lecture_search_243
# Add of existing embedding ID: lecture_search_244
# Add of existing embedding ID: lecture_search_245
# Add of existing embedding ID: lecture_search_246
# Add of existing embedding ID: lecture_search_247
# Add of existing embedding ID: lecture_search_248
# Add of existing embedding ID: lecture_search_249
# Add of existing embedding ID: lecture_search_250
# Add of existing embedding ID: lecture_search_251
# Add of existing embedding ID: lecture_search_252
# Add of existing embedding ID: lecture_search_253
# Add of existing embedding ID: lecture_search_254
# Add of existing embedding ID: lecture_search_255
# Add of existing embedding ID: lecture_search_256
# Add of existing embedding ID: lecture_search_257
# Add of existing embedding ID: lecture_search_258
# Add of existing embedding ID: lecture_search_259
# Add of existing embedding ID: lecture_search_260
# Add of existing embedding ID: lecture_search_261
# Add of existing embedding ID: lecture_search_262
# Add of existing embedding ID: lecture_search_263
# Add of existing embedding ID: lecture_search_264
# Add of existing embedding ID: lecture_search_265
# Add of existing embedding ID: lecture_search_266
# Add of existing embedding ID: lecture_search_267
# Add of existing embedding ID: lecture_search_268
# Add of existing embedding ID: lecture_search_269
# Add of existing embedding ID: lecture_search_270
# Add of existing embedding ID: lecture_search_271
# Add of existing embedding ID: lecture_search_272
# Add of existing embedding ID: lecture_search_273
# Add of existing embedding ID: lecture_search_274
# Add of existing embedding ID: lecture_search_275
# Add of existing embedding ID: lecture_search_276
# Add of existing embedding ID: lecture_search_277
# Add of existing embedding ID: lecture_search_278
# Add of existing embedding ID: lecture_search_279
# Add of existing embedding ID: lecture_search_280
# Add of existing embedding ID: lecture_search_281
# Add of existing embedding ID: lecture_search_282
# Add of existing embedding ID: lecture_search_283
# Add of existing embedding ID: lecture_search_284
# Add of existing embedding ID: lecture_search_285
# Add of existing embedding ID: lecture_search_286
# Add of existing embedding ID: lecture_search_287
# Add of existing embedding ID: lecture_search_288
# Add of existing embedding ID: lecture_search_289
# Add of existing embedding ID: lecture_search_290
# Add of existing embedding ID: lecture_search_291
# Add of existing embedding ID: lecture_search_292
# Add of existing embedding ID: lecture_search_293
# Add of existing embedding ID: lecture_search_294
# Add of existing embedding ID: lecture_search_295
# Add of existing embedding ID: lecture_search_296
# Add of existing embedding ID: lecture_search_297
# Add of existing embedding ID: lecture_search_298
# Add of existing embedding ID: lecture_search_299
# Add of existing embedding ID: lecture_search_300
# Add of existing embedding ID: lecture_search_301
# Add of existing embedding ID: lecture_search_302
# Add of existing embedding ID: lecture_search_303
# Add of existing embedding ID: lecture_search_304
# Add of existing embedding ID: lecture_search_305
# Add of existing embedding ID: lecture_search_306
# Add of existing embedding ID: lecture_search_307
# Add of existing embedding ID: lecture_search_308
# Add of existing embedding ID: lecture_search_309
# Add of existing embedding ID: lecture_search_310
# Add of existing embedding ID: lecture_search_311
# Add of existing embedding ID: lecture_search_312
# Add of existing embedding ID: lecture_search_313
# Add of existing embedding ID: lecture_search_314
# Add of existing embedding ID: lecture_search_315
# Add of existing embedding ID: lecture_search_316
# Add of existing embedding ID: lecture_search_317
# Add of existing embedding ID: lecture_search_318
# Add of existing embedding ID: lecture_search_319
# Add of existing embedding ID: lecture_search_320
# Add of existing embedding ID: lecture_search_321
# Add of existing embedding ID: lecture_search_322
# Add of existing embedding ID: lecture_search_323
# Add of existing embedding ID: lecture_search_324
# Add of existing embedding ID: lecture_search_325
# Add of existing embedding ID: lecture_search_326
# Add of existing embedding ID: lecture_search_327
# Add of existing embedding ID: lecture_search_328
# Add of existing embedding ID: lecture_search_329
# Add of existing embedding ID: lecture_search_330
# Add of existing embedding ID: lecture_search_331
# Add of existing embedding ID: lecture_search_332
# Add of existing embedding ID: lecture_search_333
# Add of existing embedding ID: lecture_search_334
# Add of existing embedding ID: lecture_search_335
# Add of existing embedding ID: lecture_search_336
# ...
# Insert of existing embedding ID: career_counsel_362
# Insert of existing embedding ID: career_counsel_363
# Insert of existing embedding ID: career_counsel_364
# Insert of existing embedding ID: career_counsel_365
# Insert of existing embedding ID: career_counsel_366
# Insert of existing embedding ID: career_counsel_367
# Insert of existing embedding ID: career_counsel_368
# Insert of existing embedding ID: career_counsel_369
# Insert of existing embedding ID: career_counsel_370
# Insert of existing embedding ID: career_counsel_371
# Insert of existing embedding ID: career_counsel_372
# Insert of existing embedding ID: career_counsel_373
# Insert of existing embedding ID: career_counsel_374
# Insert of existing embedding ID: career_counsel_375
# Insert of existing embedding ID: career_counsel_376
# Insert of existing embedding ID: career_counsel_377
# Insert of existing embedding ID: career_counsel_378
# Insert of existing embedding ID: career_counsel_379
# Insert of existing embedding ID: career_counsel_380
# Insert of existing embedding ID: career_counsel_381
# Insert of existing embedding ID: career_counsel_382
# Insert of existing embedding ID: career_counsel_383
# Insert of existing embedding ID: career_counsel_384
# Insert of existing embedding ID: career_counsel_385
# Insert of existing embedding ID: career_counsel_386
# Insert of existing embedding ID: career_counsel_387
# Insert of existing embedding ID: career_counsel_388
# Insert of existing embedding ID: career_counsel_389
# Insert of existing embedding ID: career_counsel_390
# Insert of existing embedding ID: career_counsel_391
# Insert of existing embedding ID: career_counsel_392
# Insert of existing embedding ID: career_counsel_393
# Insert of existing embedding ID: career_counsel_394
# Insert of existing embedding ID: career_counsel_395
# Insert of existing embedding ID: career_counsel_396
# Insert of existing embedding ID: career_counsel_397
# Insert of existing embedding ID: career_counsel_398
# Insert of existing embedding ID: career_counsel_399
# Insert of existing embedding ID: career_counsel_400
# Insert of existing embedding ID: career_counsel_401
# Insert of existing embedding ID: career_counsel_402
# Insert of existing embedding ID: career_counsel_403
# Insert of existing embedding ID: career_counsel_404
# Insert of existing embedding ID: career_counsel_405
# Insert of existing embedding ID: career_counsel_406
# Insert of existing embedding ID: career_counsel_407
# Insert of existing embedding ID: career_counsel_408
# Insert of existing embedding ID: career_counsel_409
# Insert of existing embedding ID: career_counsel_410
# Insert of existing embedding ID: career_counsel_411
# Insert of existing embedding ID: career_counsel_412
# Insert of existing embedding ID: career_counsel_413
# Insert of existing embedding ID: career_counsel_414
# Insert of existing embedding ID: career_counsel_415
# Insert of existing embedding ID: career_counsel_416
# Insert of existing embedding ID: career_counsel_417
# Insert of existing embedding ID: career_counsel_418
# Insert of existing embedding ID: career_counsel_419
# Insert of existing embedding ID: career_counsel_420
# Insert of existing embedding ID: career_counsel_421
# Insert of existing embedding ID: career_counsel_422
# Insert of existing embedding ID: career_counsel_423
# Insert of existing embedding ID: career_counsel_424
# Insert of existing embedding ID: career_counsel_425
# Insert of existing embedding ID: career_counsel_426
# Insert of existing embedding ID: career_counsel_427
# Insert of existing embedding ID: career_counsel_428
# Insert of existing embedding ID: career_counsel_429
# Insert of existing embedding ID: career_counsel_430
# Insert of existing embedding ID: career_counsel_431
# Insert of existing embedding ID: career_counsel_432
# Insert of existing embedding ID: career_counsel_433
# Insert of existing embedding ID: career_counsel_434
# Insert of existing embedding ID: career_counsel_435
# Insert of existing embedding ID: career_counsel_436
# Insert of existing embedding ID: career_counsel_437
# Insert of existing embedding ID: career_counsel_438
# Insert of existing embedding ID: career_counsel_439
# Insert of existing embedding ID: career_counsel_440
# Insert of existing embedding ID: career_counsel_441
# Insert of existing embedding ID: career_counsel_442
# Insert of existing embedding ID: career_counsel_443
# Insert of existing embedding ID: career_counsel_444
# Insert of existing embedding ID: career_counsel_445
# Insert of existing embedding ID: career_counsel_446
# Insert of existing embedding ID: career_counsel_447
# Insert of existing embedding ID: career_counsel_448
# Insert of existing embedding ID: career_counsel_449
# Insert of existing embedding ID: career_counsel_450
# Insert of existing embedding ID: career_counsel_451
# Insert of existing embedding ID: career_counsel_452
# Insert of existing embedding ID: career_counsel_453
# Insert of existing embedding ID: career_counsel_454
# Insert of existing embedding ID: career_counsel_455
# Insert of existing embedding ID: career_counsel_456
# Insert of existing embedding ID: career_counsel_457
# Insert of existing embedding ID: career_counsel_458
# Insert of existing embedding ID: career_counsel_459
# Insert of existing embedding ID: career_counsel_460
# Insert of existing embedding ID: career_counsel_461
# Insert of existing embedding ID: career_counsel_462
# Insert of existing embedding ID: career_counsel_463
# Insert of existing embedding ID: career_counsel_464
# Insert of existing embedding ID: career_counsel_465
# Insert of existing embedding ID: career_counsel_466
# Insert of existing embedding ID: career_counsel_467
# Insert of existing embedding ID: career_counsel_468
# Insert of existing embedding ID: career_counsel_469
# Insert of existing embedding ID: career_counsel_470
# Insert of existing embedding ID: career_counsel_471
# Insert of existing embedding ID: career_counsel_472
# Insert of existing embedding ID: career_counsel_473
# Insert of existing embedding ID: career_counsel_474
# Insert of existing embedding ID: career_counsel_475
# Insert of existing embedding ID: career_counsel_476
# Insert of existing embedding ID: career_counsel_477
# Insert of existing embedding ID: career_counsel_478
# Insert of existing embedding ID: career_counsel_479
# Insert of existing embedding ID: career_counsel_480
# Insert of existing embedding ID: career_counsel_481
# Insert of existing embedding ID: career_counsel_482
# Insert of existing embedding ID: career_counsel_483
# Insert of existing embedding ID: career_counsel_484
# Insert of existing embedding ID: career_counsel_485
# Insert of existing embedding ID: career_counsel_486
# Insert of existing embedding ID: career_counsel_487
# Insert of existing embedding ID: career_counsel_488
# Insert of existing embedding ID: career_counsel_489
# Insert of existing embedding ID: career_counsel_490
# Insert of existing embedding ID: career_counsel_491
# Insert of existing embedding ID: career_counsel_492
# Insert of existing embedding ID: career_counsel_493
# Insert of existing embedding ID: career_counsel_494
# Insert of existing embedding ID: career_counsel_495
# Insert of existing embedding ID: career_counsel_496
# Insert of existing embedding ID: career_counsel_497
# Insert of existing embedding ID: career_counsel_498
# Insert of existing embedding ID: career_counsel_499
# Insert of existing embedding ID: career_counsel_500
# Insert of existing embedding ID: career_counsel_501
# Insert of existing embedding ID: career_counsel_502
# Insert of existing embedding ID: career_counsel_503
# Insert of existing embedding ID: career_counsel_504
# Insert of existing embedding ID: career_counsel_505
# Insert of existing embedding ID: career_counsel_506
# Insert of existing embedding ID: career_counsel_507
# Insert of existing embedding ID: career_counsel_508
# Insert of existing embedding ID: career_counsel_509
# Insert of existing embedding ID: career_counsel_510
# Insert of existing embedding ID: career_counsel_511
# Insert of existing embedding ID: career_counsel_512
# Insert of existing embedding ID: career_counsel_513
# Insert of existing embedding ID: career_counsel_514
# Insert of existing embedding ID: career_counsel_515
# Insert of existing embedding ID: career_counsel_516
# Insert of existing embedding ID: career_counsel_517
# Insert of existing embedding ID: career_counsel_518
# Insert of existing embedding ID: career_counsel_519
# Insert of existing embedding ID: career_counsel_520
# Insert of existing embedding ID: career_counsel_521
# Insert of existing embedding ID: career_counsel_522
# Insert of existing embedding ID: career_counsel_523
# Insert of existing embedding ID: career_counsel_524
# Insert of existing embedding ID: career_counsel_525
# Insert of existing embedding ID: career_counsel_526
# Insert of existing embedding ID: career_counsel_527
# Insert of existing embedding ID: career_counsel_528
# Insert of existing embedding ID: career_counsel_529
# Insert of existing embedding ID: career_counsel_530
# Insert of existing embedding ID: career_counsel_531
# Insert of existing embedding ID: career_counsel_532
# Insert of existing embedding ID: career_counsel_533
# Insert of existing embedding ID: career_counsel_534
# Insert of existing embedding ID: career_counsel_535
# Insert of existing embedding ID: career_counsel_536
# Insert of existing embedding ID: career_counsel_537
# Insert of existing embedding ID: career_counsel_538
# Insert of existing embedding ID: career_counsel_539
# Insert of existing embedding ID: career_counsel_540
# Insert of existing embedding ID: career_counsel_541
# Insert of existing embedding ID: career_counsel_542
# Insert of existing embedding ID: career_counsel_543
# Insert of existing embedding ID: career_counsel_544
# Insert of existing embedding ID: career_counsel_545
# Insert of existing embedding ID: career_counsel_546
# Insert of existing embedding ID: career_counsel_547
# Insert of existing embedding ID: career_counsel_548
# Insert of existing embedding ID: career_counsel_549
# Insert of existing embedding ID: career_counsel_550
# Insert of existing embedding ID: career_counsel_551
# Insert of existing embedding ID: career_counsel_552
# Insert of existing embedding ID: career_counsel_553
# Insert of existing embedding ID: career_counsel_554
# Insert of existing embedding ID: career_counsel_555
# Insert of existing embedding ID: career_counsel_556
# Insert of existing embedding ID: career_counsel_557
# Insert of existing embedding ID: career_counsel_558
# Insert of existing embedding ID: career_counsel_559
# Insert of existing embedding ID: career_counsel_560
# Insert of existing embedding ID: career_counsel_561
# Insert of existing embedding ID: career_counsel_562
# Insert of existing embedding ID: career_counsel_563
# Insert of existing embedding ID: career_counsel_564
# Insert of existing embedding ID: career_counsel_565
# Insert of existing embedding ID: career_counsel_566
# Insert of existing embedding ID: career_counsel_567
# Insert of existing embedding ID: career_counsel_568
# Insert of existing embedding ID: career_counsel_569
# Insert of existing embedding ID: career_counsel_570
# Insert of existing embedding ID: career_counsel_571
# Insert of existing embedding ID: career_counsel_572
# Insert of existing embedding ID: career_counsel_573
# Insert of existing embedding ID: career_counsel_574
# Insert of existing embedding ID: career_counsel_575
# Insert of existing embedding ID: career_counsel_576
# Insert of existing embedding ID: career_counsel_577
# Insert of existing embedding ID: career_counsel_578
# Insert of existing embedding ID: career_counsel_579
# Insert of existing embedding ID: career_counsel_580
# Insert of existing embedding ID: career_counsel_581
# Insert of existing embedding ID: career_counsel_582
# Insert of existing embedding ID: career_counsel_583
# Insert of existing embedding ID: career_counsel_584
# Insert of existing embedding ID: career_counsel_585
# Insert of existing embedding ID: career_counsel_586
# Insert of existing embedding ID: career_counsel_587
# Insert of existing embedding ID: career_counsel_588
# Insert of existing embedding ID: career_counsel_589
# Insert of existing embedding ID: career_counsel_590
# 임베딩 개수: 591
# 벡터 차원: 1536
# Add of existing embedding ID: academic_status_0
# Add of existing embedding ID: academic_status_1
# Add of existing embedding ID: academic_status_2
# Add of existing embedding ID: academic_status_3
# Add of existing embedding ID: academic_status_4
# Add of existing embedding ID: academic_status_5
# Add of existing embedding ID: academic_status_6
# Add of existing embedding ID: academic_status_7
# Add of existing embedding ID: academic_status_8
# Add of existing embedding ID: academic_status_9
# Add of existing embedding ID: academic_status_10
# Add of existing embedding ID: academic_status_11
# Add of existing embedding ID: academic_status_12
# Add of existing embedding ID: academic_status_13
# Add of existing embedding ID: academic_status_14
# Add of existing embedding ID: academic_status_15
# Add of existing embedding ID: academic_status_16
# Add of existing embedding ID: academic_status_17
# Add of existing embedding ID: academic_status_18
# Add of existing embedding ID: academic_status_19
# Add of existing embedding ID: academic_status_20
# Add of existing embedding ID: academic_status_21
# Add of existing embedding ID: academic_status_22
# Add of existing embedding ID: academic_status_23
# Add of existing embedding ID: academic_status_24
# Add of existing embedding ID: academic_status_25
# Add of existing embedding ID: academic_status_26
# Add of existing embedding ID: academic_status_27
# Add of existing embedding ID: academic_status_28
# Add of existing embedding ID: academic_status_29
# Add of existing embedding ID: academic_status_30
# Add of existing embedding ID: academic_status_31
# Add of existing embedding ID: academic_status_32
# Add of existing embedding ID: academic_status_33
# Add of existing embedding ID: academic_status_34
# Add of existing embedding ID: academic_status_35
# Add of existing embedding ID: academic_status_36
# Add of existing embedding ID: academic_status_37
# Add of existing embedding ID: academic_status_38
# Add of existing embedding ID: academic_status_39
# Insert of existing embedding ID: academic_status_0
# Insert of existing embedding ID: academic_status_1
# Insert of existing embedding ID: academic_status_2
# Insert of existing embedding ID: academic_status_3
# Insert of existing embedding ID: academic_status_4
# Insert of existing embedding ID: academic_status_5
# Insert of existing embedding ID: academic_status_6
# Insert of existing embedding ID: academic_status_7
# Insert of existing embedding ID: academic_status_8
# Insert of existing embedding ID: academic_status_9
# Insert of existing embedding ID: academic_status_10
# Insert of existing embedding ID: academic_status_11
# Insert of existing embedding ID: academic_status_12
# Insert of existing embedding ID: academic_status_13
# Insert of existing embedding ID: academic_status_14
# Insert of existing embedding ID: academic_status_15
# Insert of existing embedding ID: academic_status_16
# Insert of existing embedding ID: academic_status_17
# Insert of existing embedding ID: academic_status_18
# Insert of existing embedding ID: academic_status_19
# Insert of existing embedding ID: academic_status_20
# Insert of existing embedding ID: academic_status_21
# Insert of existing embedding ID: academic_status_22
# Insert of existing embedding ID: academic_status_23
# Insert of existing embedding ID: academic_status_24
# Insert of existing embedding ID: academic_status_25
# Insert of existing embedding ID: academic_status_26
# Insert of existing embedding ID: academic_status_27
# Insert of existing embedding ID: academic_status_28
# Insert of existing embedding ID: academic_status_29
# Insert of existing embedding ID: academic_status_30
# Insert of existing embedding ID: academic_status_31
# Insert of existing embedding ID: academic_status_32
# Insert of existing embedding ID: academic_status_33
# Insert of existing embedding ID: academic_status_34
# Insert of existing embedding ID: academic_status_35
# Insert of existing embedding ID: academic_status_36
# Insert of existing embedding ID: academic_status_37
# Insert of existing embedding ID: academic_status_38
# Insert of existing embedding ID: academic_status_39
# 임베딩 개수: 40
# 벡터 차원: 1536

# %% [markdown]
# 사용자의 입력을 기능별로 분류
# 강의 탐색 -> 강의탐색기능
# 학습 현황 -> 학습현황기능
# 진로 상담 -> 진로상담기능

# %%
def classify_function(user_input: str) -> str:
    if "강의" in user_input or "탐색" in user_input:
        return "lecture_search"
    elif "진로" in user_input or "상담" in user_input:
        return "career_counsel"
    elif "학업" in user_input or "현황" in user_input:
        return "academic_status"
    else:
        return "lecture_search"  # fallback

# %% [markdown]
# 분류된 기능에 맞춰 ChromaDB 검색

# %%
from langchain_community.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.3)

def answer_query(user_input: str):
    task = classify_function(user_input)

    # 컬렉션 로드
    vectorstore = Chroma(
        persist_directory="./chroma_db",
        collection_name=task,
        embedding_function=embeddings_model
    )

    # 유사 문서 검색
    retriever = vectorstore.as_retriever(search_kwargs={"k": 3})
    qa = RetrievalQA.from_chain_type(llm=llm, retriever=retriever, chain_type="stuff")

    # 답변 생성
    return qa.run(user_input)

# %%
def answer_query(user_input: str, user_id: str = "kim"):
    task = classify_function(user_input)
    collection_name = task

    vectorstore = Chroma(
        persist_directory="./chroma_db",
        collection_name=collection_name,
        embedding_function=embeddings_model
    )

    prompt = PromptTemplate(
        input_variables=["context", "question"],
        template= """
        다음은 사용자의 수강 이력 또는 학업/진로 관련 정보입니다.
        질문에 답할 때 반드시 정확한 정보를 바탕으로 하세요.
    
        성적은 A+, A0, B+, B0, C+, C0, F 등의 형식이며, 
        ❗ 절대 유사한 등급을 포함하거나 추론하지 마세요.
        예: "A+"를 요청했을 경우, 반드시 성적이 "A+"인 과목만 포함하세요. "A0"는 포함하면 안 됩니다.
    
        📌 답변 형식 지침:
        - 질문에 해당하는 내용이 **여러 개인 경우 빠짐없이 모두 나열**하세요.
        -과목, 강의 추천의 경우 주어진 데이터 만을 활용하여 답변하세요. 데이터에 없는 과목은 언급하지 마세요.
        -중복되는 단어는 한번만 언급하세요.
        - 질문 유형에 따라 말끝을 다르게 쓰세요.
          예:
            - "내가 A+ 받은 과목 알려줘" → "OOO, OOO 과목에서 A+를 받으셨습니다."
            - "자료구조 성적이 뭐야?" → "자료구조의 성적은 B+입니다."
            - "객체지향프로그래밍이 전선이지?" → "네, 객체지향프로그래밍은 전필입니다."
            - "전체 평균이 어떻게 돼?" → "전체 성적 평균은 3.58입니다."
        - 정중하고 간결하게, 핵심만 자연스럽게 응답하세요.
        - 축하 인사, 추가 질문 권유 등은 하지 마세요.
    
        문서:
        {context}
    
        질문:
        {question}
    
        이 지침을 따라 정확하고 정중하게 답변하세요.
        """
    )

    qa = RetrievalQA.from_chain_type(
        llm=llm,
        retriever=vectorstore.as_retriever(search_kwargs={"k": 20}),
        chain_type="stuff",
        chain_type_kwargs={"prompt": prompt}
    )

    return qa.invoke({"query": user_input})["result"]

# %%
answer_query(user_input="내가 A+ 받은 과목 알려줘", user_id="kim")
# Out:
# '- AI빅데이터의이해, AI멀티미디어활용 과목에서 A+를 받으셨습니다.'

# %%
query = "팀플 없는 전공 추천해줘 "
print(answer_query(query))
# Out:
# 답변: C프로그래밍 강의는 팀플이 없는 강의입니다.

# %%
query = "나 재수강 총 몇번 했나? "
print(answer_query(query))
# Out:
# 재수강 횟수는 총 4번입니다.
